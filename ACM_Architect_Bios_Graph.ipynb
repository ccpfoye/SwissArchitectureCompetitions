# %% [markdown]
# # Morphe Metadata Graph - ACM Datasets
#
# We want to load the fetched metadata from the ACM dataset, based on the author bios.
#
# For now, let's stick with people. We will use the following `cpfRelationType` values:
#
#     - "family" : This person is a family member to the current architect
#     - "associative" : This entity or person is related to the current architect. Usually a collaboration!
#
# Unused `cpfRelationType` values:
#
#     - "subjectOf": somehow involved in this project
#     - "creatorOf": somehow created this project.

# %%
import xml.etree.ElementTree as ET

# Register the namespace
namespaces = {
    'eac': 'urn:isbn:1-931666-33-4',
    'xlink': 'http://www.w3.org/1999/xlink'
}

# Parse the XML file or string
tree = ET.parse('Data/ACM/bios/alphonse-laverriere-bio.xml')  # or use ET.fromstring(xml_string) if you have it as a string
root = tree.getroot()

# Example: Get recordId
record_id = root.find('.//eac:recordId', namespaces)
print("Record ID:", record_id.text)

# Example: Get entity name
name_part = root.find('.//eac:nameEntry/eac:part', namespaces)
print("Name:", name_part.text)

# Example: Get the biographical history text
biog_hist = root.find('.//eac:biogHist/eac:p', namespaces)
print("Bio:", biog_hist.text.strip())

# Example: Get all related persons/entities
relations = root.findall('.//eac:cpfRelation', namespaces)
for rel in relations:
    name = rel.find('eac:relationEntry', namespaces)
    href = rel.attrib.get(f'{{{namespaces["xlink"]}}}href')
    print(f"Related to: {name.text}, link: {href}")
# Out:
# Record ID: Acm - Alphonse Laverrière
# Name: Alphonse Laverrière
# Bio: Architecte ENSBA (Atelier Pascal) FAS, fondateur de l’Œuvre, directeur de l’École cantonale de dessin à Lausanne, professeur de théorie de l’architecture au Polytechnicum de Zurich. L'activité variée qu'il a à Lausanne, à Genève et en Haute-Savoie lui permet d’afficher une carrière au cours de laquelle les programmes les plus prestigieux lui sont offerts: à Lausanne: Pont Chauderon, Gare CFF, Hôtel de la Paix, Librairie et éditions Payot, Siège de la Banque fédérale SA, Tribunal fédéral. Laverrière est remarqué pour son aptitude à gagner des concours, c’est ainsi qu’il réalise le Monument international de la réformation à Genève.
# Membre FAS dès 1916.
# Related to: Ferdinand Jacques Meyrat, link: https://morphe.epfl.ch/index.php/ferdinand-jacques-meyrat
# Related to: Jean Taillens, link: https://morphe.epfl.ch/index.php/jean-taillens-et-charles-dubois
# Related to: L'Œuvre (OEV), link: https://morphe.epfl.ch/index.php/loeuvre
# Related to: Eugène Monod, link: https://morphe.epfl.ch/index.php/eugene-monod
# Related to: Menuiserie Modèle Albert Held &amp; Cie. SA, Montreux, link: https://morphe.epfl.ch/index.php/menuiserie-modele-montreux
# Related to: Pierre Quillet, link: https://morphe.epfl.ch/index.php/pierre-quillet
# Related to: Paul Lavenex, link: https://morphe.epfl.ch/index.php/paul-lavenex
# Related to: Fédération des Architectes Suisses (FAS) = Bund Schweizer Architekten (BSA), link: https://morphe.epfl.ch/index.php/federation-des-architectes-suisses-fas-bund-schweizer-architekten-bsa

# %% [markdown]
# chatgpt attempt

# %%
import os
import requests
import xml.etree.ElementTree as ET
import networkx as nx

# Register namespaces for eac-cpf
NS = {
    'eac': 'urn:isbn:1-931666-33-4',
    'xlink': 'http://www.w3.org/1999/xlink'
}


def parse_eac_cpf(xml_content):
    """
    Parse the XML content (string) of an EAC-CPF record.
    Returns:
      person_name (str): The main person's name in <nameEntry><part>
      relations (list of tuples): Each tuple is (relation_type, related_name, related_url)
                                  e.g. ('family', 'John Smith', 'https://morphe.epfl.ch/...')
    """
    root = ET.fromstring(xml_content)

    # Extract the main person's name
    name_el = root.find('.//eac:nameEntry/eac:part', NS)
    person_name = name_el.text.strip() if name_el is not None else "Unknown"
    print(f"Adding {person_name}'s relations.")

    relations = []
    # Find all <cpfRelation> elements
    cpf_relations = root.findall('.//eac:cpfRelation', NS)
    for rel in cpf_relations:
        rel_type = rel.attrib.get('cpfRelationType', '').strip()
        # For demonstration, let's fetch all. If you only want certain types, adapt the condition.
        if rel_type in ["family", "associative"] or True:
            rel_name_el = rel.find('eac:relationEntry', NS)
            print(f"    Adding person {rel_name_el} of rel_type {rel_type}.")
            rel_name = rel_name_el.text.strip() if rel_name_el is not None else "Unknown"
            xlink_href = rel.attrib.get(f'{{{NS["xlink"]}}}href', '')
            relations.append((rel_type, rel_name, xlink_href))

    return person_name, relations

def build_eac_url(href):
    """
    Given a base href like 'https://morphe.epfl.ch/index.php/paul-lavenex',
    build the URL needed to fetch the EAC-CPF XML by appending
    ';eac?sf_format=xml'.
    """
    return href + ";eac?sf_format=xml"

def add_person_to_graph(person_name):
    """
    Add a person node to the graph if it doesn't already exist.
    """
    if not graph.has_node(person_name):
        graph.add_node(person_name)

def add_relation_edge(source_name, target_name, relation_type):
    """
    Add an edge from source to target in the graph, labeled by relation_type,
    only if it doesn't already exist.
    """
    if not graph.has_edge(source_name, target_name):
        graph.add_edge(source_name, target_name, relation=relation_type)

def save_fetched_file(xml_url, content, directory):
    """
    Saves the fetched XML content to the given directory, using a filename derived from the URL.
    """
    # Make sure directory exists
    os.makedirs(directory, exist_ok=True)

    # Derive a safe filename from the URL
    filename = href_to_filename(xml_url)
    path = os.path.join(directory, filename)

    with open(path, 'w', encoding='utf-8') as f:
        f.write(content)

    print(f"File saved: {path}")

def href_to_filename(url):
    """
    Convert the URL into a safe filename.
    Removes 'https://', '/', '?' and so forth, turning them into underscores.
    """
    import re
    base = re.sub(r'[^A-Za-z0-9._-]+', '_', url)
    return base + ".xml"

def process_record_from_url(xml_url, save_directory):
    """
    Recursively parse the EAC-CPF record from a URL, add the node/edges
    to the graph, then follow its relations. Avoid re-processing if visited.
    """
    # If we've already processed this link, return
    if xml_url in visited_links:
        return
    visited_links.add(xml_url)

    print(f"Fetching {xml_url}")
    resp = requests.get(xml_url)
    if resp.status_code != 200:
        print(f"WARNING: Could not fetch {xml_url} (status {resp.status_code})")
        return

    content = resp.text

    # Save the fetched XML to the directory
    save_fetched_file(xml_url, content, save_directory)

    # Parse the newly fetched XML
    person_name, relations = parse_eac_cpf(content)

    # Add the main person as a node
    add_person_to_graph(person_name)

    # For each relation, add the node and edge, then recurse
    for rel_type, rel_name, rel_href in relations:
        add_person_to_graph(rel_name)
        add_relation_edge(person_name, rel_name, rel_type)
        
        # If rel_href is non-empty, fetch it
        if rel_href:
            new_url = build_eac_url(rel_href)
            process_record_from_url(new_url, save_directory)

def process_local_file(filepath, save_directory):
    """
    Parse one local EAC-CPF XML file, add its person node,
    and follow its remote links recursively.
    """
    print(f"Processing local file: {filepath}")
    with open(filepath, "r", encoding="utf-8") as f:
        xml_content = f.read()

    # Parse
    person_name, relations = parse_eac_cpf(xml_content)
    add_person_to_graph(person_name)

    # For each relation, add node+edge, then fetch that link
    for rel_type, rel_name, rel_href in relations:
        add_person_to_graph(rel_name)
        add_relation_edge(person_name, rel_name, rel_type)
        if rel_href:
            new_url = build_eac_url(rel_href)
            process_record_from_url(new_url, save_directory)

def build_full_graph_from_directory(directory_path, save_directory):
    """
    Iterate over all XML files in the given directory. For each:
      - Parse the local file
      - Add its node & edges
      - Recursively fetch remote links and parse them
      - Save the fetched remote files to `save_directory`
    """
    for filename in os.listdir(directory_path):
        if filename.lower().endswith(".xml"):
            file_path = os.path.join(directory_path, filename)
            process_local_file(file_path, save_directory)

    print("Done building graph.")

# %%
    
# Create a global graph
graph = nx.Graph()

# To avoid re-fetching and re-processing the same links multiple times
visited_links = set()
    
input_directory = "Data/ACM/bios"       # your local directory of EAC-CPF files
fetched_save_dir = "Data/ACM/fetched_bios"   # directory where remote EAC-CPF files are stored

build_full_graph_from_directory(input_directory, fetched_save_dir)

print("\nFinal graph nodes:")
print(graph.nodes())

print("\nFinal graph edges:")
for u, v, data in graph.edges(data=True):
    print(f"  {u} --({data['relation']})--> {v}")

# For example, you can write it to a GraphML
nx.write_graphml(graph, "people_relations.graphml")
nx.write_gexf(graph, "people_relations.gexf")
# Out:
# Processing local file: Data/ACM/bios/jacques-de-freudenreich-bio.xml
# Adding Jacques de Freudenreich's relations.
# Processing local file: Data/ACM/bios/casimir-reymond-bio.xml
# Adding Casimir Reymond's relations.
# Processing local file: Data/ACM/bios/alexandre-antipas-bio.xml
# Adding Alexandre Antipas's relations.
# Processing local file: Data/ACM/bios/heidi-wenger-bio.xml
# Adding Heidi Wenger's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae00bd0> of rel_type family.
# Fetching https://morphe.epfl.ch/index.php/peter-wenger;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_peter-wenger_eac_sf_format_xml.xml
# Adding Peter Wenger's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae01120> of rel_type family.
# Fetching https://morphe.epfl.ch/index.php/heidi-wenger;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_heidi-wenger_eac_sf_format_xml.xml
# Adding Heidi Wenger's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae01bc0> of rel_type family.
# Processing local file: Data/ACM/bios/charles-francois-thevenaz-bio.xml
# Adding Charles-François Thévenaz's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae00450> of rel_type family.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae00a90> of rel_type family.
# Fetching https://morphe.epfl.ch/index.php/charles-philippe-thevenaz;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_charles-philippe-thevenaz_eac_sf_format_xml.xml
# Adding Charles-Philippe Thévenaz's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae01850> of rel_type family.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae00d60> of rel_type family.
# Fetching https://morphe.epfl.ch/index.php/charles-francois-thevenaz-2;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_charles-francois-thevenaz-2_eac_sf_format_xml.xml
# Adding Charles-François Thévenaz's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae00b30> of rel_type family.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae01b70> of rel_type family.
# Fetching https://morphe.epfl.ch/index.php/charles-thevenaz;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_charles-thevenaz_eac_sf_format_xml.xml
# Adding Charles Thévenaz's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae02070> of rel_type family.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae02110> of rel_type family.
# Processing local file: Data/ACM/bios/jacques-nobile-bio.xml
# Adding Jacques Nobile's relations.
# Processing local file: Data/ACM/bios/vincent-mangeat-bio.xml
# Adding Vincent Mangeat's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae01580> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae00450> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/pierre-foretay;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_pierre-foretay_eac_sf_format_xml.xml
# Adding Pierre Foretay's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae02750> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/vincent-mangeat;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_vincent-mangeat_eac_sf_format_xml.xml
# Adding Vincent Mangeat's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae02b10> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae02a70> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/federation-des-architectes-suisses-fas-bund-schweizer-architekten-bsa;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_federation-des-architectes-suisses-fas-bund-schweizer-architekten-bsa_eac_sf_format_xml.xml
# Adding Fédération des Architectes Suisses (FAS) = Bund Schweizer Architekten (BSA)'s relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae01ad0> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae007c0> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae01cb0> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae004f0> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae016c0> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae01440> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae00f90> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae00ea0> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae00220> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae022f0> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae02340> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae02430> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae024d0> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae02570> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae02610> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae02070> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae00fe0> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae014e0> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae019e0> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae01300> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae00180> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae01a30> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae013f0> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae00680> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae013a0> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae00450> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae00630> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae00950> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae00270> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae01850> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae02700> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/renato-salvi;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_renato-salvi_eac_sf_format_xml.xml
# Adding Renato Salvi's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae01c10> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae01f30> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae00ef0> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/flora-ruchat-roncati;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_flora-ruchat-roncati_eac_sf_format_xml.xml
# Adding Flora Ruchat-Roncati's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae01800> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae01620> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/communaute-de-travail-la-transjurane;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_communaute-de-travail-la-transjurane_eac_sf_format_xml.xml
# Adding Communauté de Travail la Transjurane's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae28810> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae286d0> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/georges-brera-2;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_georges-brera-2_eac_sf_format_xml.xml
# Adding Georges Brera's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae02070> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae027f0> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae00450> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/paul-waltenspuhl;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_paul-waltenspuhl_eac_sf_format_xml.xml
# Adding Paul Waltenspühl's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae03650> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae002c0> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/jean-marie-ellenberger;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_jean-marie-ellenberger_eac_sf_format_xml.xml
# Adding Jean-Marie Ellenberger's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae01cb0> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae019e0> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae01bc0> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae027f0> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/jean-jacques-gerber;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_jean-jacques-gerber_eac_sf_format_xml.xml
# Adding Jean-Jacques Gerber's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae037e0> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/bernard-mocellin;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_bernard-mocellin_eac_sf_format_xml.xml
# Adding Bernard Mocellin's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae34040> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/andre-leman;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_andre-leman_eac_sf_format_xml.xml
# Adding André Leman's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae24270> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/max-schlup;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_max-schlup_eac_sf_format_xml.xml
# Adding Max Schlup's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae02a20> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/jakob-zweifel;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_jakob-zweifel_eac_sf_format_xml.xml
# Adding Jakob Zweifel's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae017b0> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae03600> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae03470> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae02700> of rel_type hierarchical.
# Fetching https://morphe.epfl.ch/index.php/h-massler;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_h-massler_eac_sf_format_xml.xml
# Adding H. Massler's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae034c0> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae00630> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/team-j-zweifel;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_team-j-zweifel_eac_sf_format_xml.xml
# Adding Team J. Zweifel's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae24310> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae246d0> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae24900> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae24b30> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae24d60> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae24f90> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae25120> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae251c0> of rel_type hierarchical.
# Fetching https://morphe.epfl.ch/index.php/w-maurer;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_w-maurer_eac_sf_format_xml.xml
# Adding W. Maurer's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae24ef0> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae250d0> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae259e0> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/w-christen;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_w-christen_eac_sf_format_xml.xml
# Adding W. Christen's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae11260> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae11580> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae117b0> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae119e0> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/zweifel-strickler-associes;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_zweifel-strickler-associes_eac_sf_format_xml.xml
# Adding Zweifel, Strickler et Associés's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae125c0> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae127a0> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae128e0> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae12980> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae12bb0> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae12de0> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae13010> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae13240> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/communaute-de-travail-pour-la-construction-de-ruraux-type-expo-64;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_communaute-de-travail-pour-la-construction-de-ruraux-type-expo-64_eac_sf_format_xml.xml
# Adding Communauté de travail pour la construction de ruraux type expo 64's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae13600> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae13330> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae12160> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae122a0> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae11f80> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae108b0> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae11120> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/a-s-c-a;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_a-s-c-a_eac_sf_format_xml.xml
# Adding A.S.C.A's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae136f0> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/s-v-i-l;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_s-v-i-l_eac_sf_format_xml.xml
# Adding S.V.I.L's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae10ae0> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae132e0> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/communaute-de-travail-bureau-zweifel-strickler-u-s-p-s-v-i-l;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_communaute-de-travail-bureau-zweifel-strickler-u-s-p-s-v-i-l_eac_sf_format_xml.xml
# Adding Communauté de travail bureau Zweifel + Strickler, U.S.P, S.V.I.L's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae11da0> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae129d0> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae11e90> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae109f0> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae11b20> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae13c90> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae13ec0> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/u-s-p-office-de-la-construction-lausanne-brugg;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_u-s-p-office-de-la-construction-lausanne-brugg_eac_sf_format_xml.xml
# Adding U.S.P (Office de la construction Lausanne + Brugg)'s relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae10f40> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae138d0> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/uli-huber;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_uli-huber_eac_sf_format_xml.xml
# Adding Uli Huber's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae10950> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae13f10> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae10a40> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae1c1d0> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/maggia-sa;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_maggia-sa_eac_sf_format_xml.xml
# Adding Maggia SA's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae10ae0> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae13510> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae10c20> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae10b80> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/gerua-2;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_gerua-2_eac_sf_format_xml.xml
# Adding GERUA Groupe d'études de réalisation, Université de Annaba's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae13010> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae135b0> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae13f60> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae13f10> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/bonnard-gardel-pool-dingenieurs;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_bonnard-gardel-pool-dingenieurs_eac_sf_format_xml.xml
# Adding Bonnard & Gardel's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae13380> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae136f0> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae10ef0> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/pool-dingenieurs-2;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_pool-dingenieurs-2_eac_sf_format_xml.xml
# Adding Pool d'ingénieurs's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae13dd0> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/gruner-ag;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_gruner-ag_eac_sf_format_xml.xml
# Adding Gruner AG's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae12c00> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae10900> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/h-menig;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_h-menig_eac_sf_format_xml.xml
# Adding H. Menig's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae10450> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/guido-cocchi;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_guido-cocchi_eac_sf_format_xml.xml
# Adding Guido Cocchi's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae007c0> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae00630> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/aaa-ad-decoppet-alin-part;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_aaa-ad-decoppet-alin-part_eac_sf_format_xml.xml
# Adding AAA/AD DECOPPET, Alin & part.'s relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae02660> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae027f0> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae01da0> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae00310> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae02480> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae02f70> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae01710> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae01d50> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae01bc0> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae02020> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae00e00> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/jacques-barbier;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_jacques-barbier_eac_sf_format_xml.xml
# Adding Jacques Barbier's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae119e0> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/jean-brugge;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_jean-brugge_eac_sf_format_xml.xml
# Adding Jean Brugger's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae104a0> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/alin-decoppet;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_alin-decoppet_eac_sf_format_xml.xml
# Adding Alin Décoppet's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae11800> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae11620> of rel_type .
# Fetching https://morphe.epfl.ch/index.php/ecole-polytechnique-federale-de-lausanne-epfl;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_ecole-polytechnique-federale-de-lausanne-epfl_eac_sf_format_xml.xml
# Adding École polytechnique fédérale de Lausanne (EPFL)'s relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae11c10> of rel_type .
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae10400> of rel_type .
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae114e0> of rel_type .
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae10630> of rel_type .
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae11760> of rel_type .
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae10720> of rel_type .
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae121b0> of rel_type .
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae12480> of rel_type .
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae13740> of rel_type .
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae12de0> of rel_type .
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae11e40> of rel_type .
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae13010> of rel_type .
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae11670> of rel_type .
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae132e0> of rel_type temporal-earlier.
# Fetching https://morphe.epfl.ch/index.php/hubert-gillieron;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_hubert-gillieron_eac_sf_format_xml.xml
# Adding Hubert Gilliéron's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae110d0> of rel_type .
# Fetching https://morphe.epfl.ch/index.php/pierre-von-meiss;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_pierre-von-meiss_eac_sf_format_xml.xml
# Adding Pierre von Meiss's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae12890> of rel_type .
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae12e80> of rel_type .
# Fetching https://morphe.epfl.ch/index.php/ecole-polytechnique-de-luniversite-de-lausanne-epul;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_ecole-polytechnique-de-luniversite-de-lausanne-epul_eac_sf_format_xml.xml
# Adding École polytechnique de l'Université de Lausanne (EPUL)'s relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae13f10> of rel_type .
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae11440> of rel_type .
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae109f0> of rel_type .
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae12070> of rel_type .
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae11d50> of rel_type .
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae107c0> of rel_type .
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae122f0> of rel_type .
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae124d0> of rel_type temporal-earlier.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae136f0> of rel_type temporal-earlier.
# Fetching https://morphe.epfl.ch/index.php/jean-pierre-vouga;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_jean-pierre-vouga_eac_sf_format_xml.xml
# Adding Jean-Pierre Vouga's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae130b0> of rel_type family.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae10f40> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae12700> of rel_type .
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae138d0> of rel_type .
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae1c1d0> of rel_type .
# Fetching https://morphe.epfl.ch/index.php/bernard-vouga;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_bernard-vouga_eac_sf_format_xml.xml
# Adding Bernard Vouga's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae11ad0> of rel_type family.
# Fetching https://morphe.epfl.ch/index.php/ecole-nationale-superieure-des-beaux-arts-paris;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_ecole-nationale-superieure-des-beaux-arts-paris_eac_sf_format_xml.xml
# Adding Ecole nationale supérieure des beaux-arts, Paris's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae12750> of rel_type .
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae11800> of rel_type .
# Fetching https://morphe.epfl.ch/index.php/louis-viollier;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_louis-viollier_eac_sf_format_xml.xml
# Adding Louis Viollier's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae1c7c0> of rel_type .
# Fetching https://morphe.epfl.ch/index.php/jean-stengelin;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_jean-stengelin_eac_sf_format_xml.xml
# Adding Jean Stengelin's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae12840> of rel_type .
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae124d0> of rel_type .
# Fetching https://morphe.epfl.ch/index.php/jacques-favre;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_jacques-favre_eac_sf_format_xml.xml
# Adding Jacques Favre's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae12160> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae12e30> of rel_type .
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae12200> of rel_type .
# Fetching https://morphe.epfl.ch/index.php/bernard-murisier;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_bernard-murisier_eac_sf_format_xml.xml
# Adding Bernard Murisier's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae12750> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae12570> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/jacques-favarger;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_jacques-favarger_eac_sf_format_xml.xml
# Adding Jacques Favarger's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae1c9f0> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae1ca90> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae1cb80> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/gaston-gorjat;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_gaston-gorjat_eac_sf_format_xml.xml
# Adding Gaston Gorjat's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae1d1c0> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae1d170> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/robert-baehler;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_robert-baehler_eac_sf_format_xml.xml
# Adding Robert Baehler's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae1c900> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/roger-gonet;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_roger-gonet_eac_sf_format_xml.xml
# Adding Roger Gonet's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae1c860> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/jean-pierre-daxelhofer;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_jean-pierre-daxelhofer_eac_sf_format_xml.xml
# Adding Jean-Pierre Daxelhofer's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae125c0> of rel_type .
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae13c90> of rel_type .
# Fetching https://morphe.epfl.ch/index.php/maurice-cosandey-2;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_maurice-cosandey-2_eac_sf_format_xml.xml
# Adding Maurice Cosandey's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae11760> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae12a70> of rel_type .
# Fetching https://morphe.epfl.ch/index.php/zwahlen-mayr-sa;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_zwahlen-mayr-sa_eac_sf_format_xml.xml
# Adding Zwahlen & Mayr SA's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae13b00> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/jean-louis-ruche;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_jean-louis-ruche_eac_sf_format_xml.xml
# Adding Jean-Louis Ruche's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae127f0> of rel_type family.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae12de0> of rel_type .
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae12750> of rel_type .
# Fetching https://morphe.epfl.ch/index.php/maurice-ruche-2;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_maurice-ruche-2_eac_sf_format_xml.xml
# Adding Maurice Ruche's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae1cb30> of rel_type family.
# Fetching https://morphe.epfl.ch/index.php/jean-tschumi;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_jean-tschumi_eac_sf_format_xml.xml
# Adding Jean Tschumi's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae11030> of rel_type family.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae10540> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae10950> of rel_type .
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae1cb30> of rel_type .
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae1fb00> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/bernard-tschumi;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_bernard-tschumi_eac_sf_format_xml.xml
# Adding Bernard Tschumi's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae1f920> of rel_type family.
# Fetching https://morphe.epfl.ch/index.php/pierre-bonnard;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_pierre-bonnard_eac_sf_format_xml.xml
# Adding Pierre Bonnard's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae1f420> of rel_type family.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae1f240> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/rene-bonnard;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_rene-bonnard_eac_sf_format_xml.xml
# Adding René Bonnard's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae1ede0> of rel_type family.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae1ebb0> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/edouard-boy-de-la-tour;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_edouard-boy-de-la-tour_eac_sf_format_xml.xml
# Adding Edouard Boy de la Tour-Pilet's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae1e5c0> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/lucio-di-clemente;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_lucio-di-clemente_eac_sf_format_xml.xml
# Adding Lucio Di Clemente's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae1ee80> of rel_type .
# Fetching https://morphe.epfl.ch/index.php/ecole-dingenieurs-de-lausanne;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_ecole-dingenieurs-de-lausanne_eac_sf_format_xml.xml
# Adding École d'ingénieurs de l'Université de Lausanne's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae11760> of rel_type temporal-earlier.
# Fetching https://morphe.epfl.ch/index.php/ph-h-bovy;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_ph-h-bovy_eac_sf_format_xml.xml
# Adding Philippe-H. Bovy's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae11530> of rel_type .
# Fetching https://morphe.epfl.ch/index.php/alain-g-tschumi;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_alain-g-tschumi_eac_sf_format_xml.xml
# Adding Alain-G. Tschumi's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae12890> of rel_type .
# Fetching https://morphe.epfl.ch/index.php/ines-lamuniere;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_ines-lamuniere_eac_sf_format_xml.xml
# Adding Inès Lamunière's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae13a60> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae132e0> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae11620> of rel_type .
# Fetching https://morphe.epfl.ch/index.php/gabriel-de-freudenreich;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_gabriel-de-freudenreich_eac_sf_format_xml.xml
# Adding Gabriel de Freudenreich's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae12840> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae12980> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae131a0> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae13e20> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae12b10> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae139c0> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/andre-gaillard;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_andre-gaillard_eac_sf_format_xml.xml
# Adding André Gaillard's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae12020> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae134c0> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/luigi-snozzi;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_luigi-snozzi_eac_sf_format_xml.xml
# Adding Luigi Snozzi's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae12de0> of rel_type .
# Fetching https://morphe.epfl.ch/index.php/jean-claude-badoux;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_jean-claude-badoux_eac_sf_format_xml.xml
# Adding Jean-Claude Badoux's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae13740> of rel_type .
# Fetching https://morphe.epfl.ch/index.php/theodore-bovet;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_theodore-bovet_eac_sf_format_xml.xml
# Adding Théodore Bovet's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae12f20> of rel_type .
# Fetching https://morphe.epfl.ch/index.php/nicolaus-herkommer;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_nicolaus-herkommer_eac_sf_format_xml.xml
# Adding Nicolaus Herkommer's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae033d0> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/nicolas-petrovitch-niegoch;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_nicolas-petrovitch-niegoch_eac_sf_format_xml.xml
# Adding Nicolas Petrovitch-Niegoch's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae00f90> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/pierre-rittmeyer;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_pierre-rittmeyer_eac_sf_format_xml.xml
# Adding Pierre Rittmeyer's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae02ed0> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/leopold-veuve;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_leopold-veuve_eac_sf_format_xml.xml
# Adding Léopold Veuve's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae02570> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/rene-vittone;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_rene-vittone_eac_sf_format_xml.xml
# Adding René Vittone's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae02480> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/michel-weber;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_michel-weber_eac_sf_format_xml.xml
# Adding Michel-Robert Weber's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae02700> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/roland-willomet;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_roland-willomet_eac_sf_format_xml.xml
# Adding Roland Willomet's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae02a20> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/jean-marie-yokoyama;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_jean-marie-yokoyama_eac_sf_format_xml.xml
# Adding Jean-Marie Yokoyama's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae02340> of rel_type associative.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae007c0> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/etic-j-m-yokoyama;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_etic-j-m-yokoyama_eac_sf_format_xml.xml
# Adding ETIC J.-M. Yokoyama's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae02de0> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/alberto-camenzind;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_alberto-camenzind_eac_sf_format_xml.xml
# Adding Alberto Camenzind's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae01120> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/florian-vischer;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_florian-vischer_eac_sf_format_xml.xml
# Adding Florian Vischer's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae007c0> of rel_type associative.
# Fetching https://morphe.epfl.ch/index.php/alberto-sartoris;eac?sf_format=xml
# File saved: Data/ACM/fetched_bios/https_morphe.epfl.ch_index.php_alberto-sartoris_eac_sf_format_xml.xml
# Adding Alberto Sartoris's relations.
#     Adding person <Element '{urn:isbn:1-931666-33-4}relationEntry' at 0x7fb0fae01bc0> of rel_type family.
# ...
#
# Final graph edges:
#   Heidi Wenger --(family)--> Peter Wenger
#   Charles-François Thévenaz --(family)--> Charles-Philippe Thévenaz
#   Charles-François Thévenaz --(family)--> Charles Thévenaz
#   Charles-Philippe Thévenaz --(family)--> Charles Thévenaz
#   Vincent Mangeat --(associative)--> Pierre Foretay
#   Vincent Mangeat --(associative)--> Fédération des Architectes Suisses (FAS) = Bund Schweizer Architekten (BSA)
#   Fédération des Architectes Suisses (FAS) = Bund Schweizer Architekten (BSA) --(associative)--> Renato Salvi
#   Fédération des Architectes Suisses (FAS) = Bund Schweizer Architekten (BSA) --(associative)--> Georges Brera
#   Fédération des Architectes Suisses (FAS) = Bund Schweizer Architekten (BSA) --(associative)--> Paul Waltenspühl
#   Fédération des Architectes Suisses (FAS) = Bund Schweizer Architekten (BSA) --(associative)--> Max Schlup
#   Fédération des Architectes Suisses (FAS) = Bund Schweizer Architekten (BSA) --(associative)--> Jakob Zweifel
#   Fédération des Architectes Suisses (FAS) = Bund Schweizer Architekten (BSA) --(associative)--> Guido Cocchi
#   Fédération des Architectes Suisses (FAS) = Bund Schweizer Architekten (BSA) --(associative)--> Jean-Pierre Vouga
#   Fédération des Architectes Suisses (FAS) = Bund Schweizer Architekten (BSA) --(associative)--> Jean Tschumi
#   Fédération des Architectes Suisses (FAS) = Bund Schweizer Architekten (BSA) --(associative)--> Gabriel de Freudenreich
#   Fédération des Architectes Suisses (FAS) = Bund Schweizer Architekten (BSA) --(associative)--> Jean-Marie Yokoyama
#   Fédération des Architectes Suisses (FAS) = Bund Schweizer Architekten (BSA) --(associative)--> Alberto Camenzind
#   Fédération des Architectes Suisses (FAS) = Bund Schweizer Architekten (BSA) --(associative)--> Florian Vischer
#   Fédération des Architectes Suisses (FAS) = Bund Schweizer Architekten (BSA) --(associative)--> Alberto Sartoris
#   Fédération des Architectes Suisses (FAS) = Bund Schweizer Architekten (BSA) --(associative)--> Maurice Turettini
#   Fédération des Architectes Suisses (FAS) = Bund Schweizer Architekten (BSA) --(associative)--> Paul Lavenex
#   Fédération des Architectes Suisses (FAS) = Bund Schweizer Architekten (BSA) --(associative)--> Georges Epitaux
#   Fédération des Architectes Suisses (FAS) = Bund Schweizer Architekten (BSA) --(associative)--> Alphonse Laverrière
#   Fédération des Architectes Suisses (FAS) = Bund Schweizer Architekten (BSA) --(associative)--> Frédéric Gilliard
#   Fédération des Architectes Suisses (FAS) = Bund Schweizer Architekten (BSA) --(associative)--> Pierre Zoelly
#   Fédération des Architectes Suisses (FAS) = Bund Schweizer Architekten (BSA) --(associative)--> Georges-Jacques Haefeli
#   Fédération des Architectes Suisses (FAS) = Bund Schweizer Architekten (BSA) --(associative)--> Arthur Lozeron
#   Fédération des Architectes Suisses (FAS) = Bund Schweizer Architekten (BSA) --(associative)--> Robert Loup
#   Fédération des Architectes Suisses (FAS) = Bund Schweizer Architekten (BSA) --(associative)--> Jean Pythoud
#   Fédération des Architectes Suisses (FAS) = Bund Schweizer Architekten (BSA) --(associative)--> Janos Farago
#   Fédération des Architectes Suisses (FAS) = Bund Schweizer Architekten (BSA) --(associative)--> Maurice Billeter
#   Fédération des Architectes Suisses (FAS) = Bund Schweizer Architekten (BSA) --(associative)--> Jeanne Bueche
#   Fédération des Architectes Suisses (FAS) = Bund Schweizer Architekten (BSA) --(associative)--> Marc Piccard
#   Fédération des Architectes Suisses (FAS) = Bund Schweizer Architekten (BSA) --(associative)--> Max Bill
#   Fédération des Architectes Suisses (FAS) = Bund Schweizer Architekten (BSA) --(associative)--> Eduard Lanz
#   Renato Salvi --(associative)--> Flora Ruchat-Roncati
#   Renato Salvi --(associative)--> Communauté de Travail la Transjurane
#   Flora Ruchat-Roncati --(associative)--> Communauté de Travail la Transjurane
#   Georges Brera --(associative)--> Paul Waltenspühl
#   Georges Brera --(associative)--> Jean-Marie Ellenberger
#   Jean-Marie Ellenberger --(associative)--> Jean-Jacques Gerber
#   Jean-Marie Ellenberger --(associative)--> Bernard Mocellin
#   Jean-Marie Ellenberger --(associative)--> André Leman
#   Jakob Zweifel --(associative)--> H. Massler
#   Jakob Zweifel --(associative)--> Zweifel, Strickler et Associés
#   Jakob Zweifel --(hierarchical)--> Team J. Zweifel
#   H. Massler --(associative)--> Team J. Zweifel
#   Team J. Zweifel --(associative)--> W. Maurer
#   Team J. Zweifel --(associative)--> Communauté de travail bureau Zweifel + Strickler, U.S.P, S.V.I.L
#   Team J. Zweifel --(associative)--> Uli Huber
#   Team J. Zweifel --(associative)--> Communauté de travail pour la construction de ruraux type expo 64
#   Team J. Zweifel --(associative)--> W. Christen
#   Team J. Zweifel --(associative)--> H. Menig
#   W. Maurer --(associative)--> W. Christen
#   W. Maurer --(associative)--> Communauté de travail bureau Zweifel + Strickler, U.S.P, S.V.I.L
#   W. Christen --(associative)--> Zweifel, Strickler et Associés
#   W. Christen --(associative)--> Communauté de travail bureau Zweifel + Strickler, U.S.P, S.V.I.L
#   Zweifel, Strickler et Associés --(associative)--> Communauté de travail pour la construction de ruraux type expo 64
#   Zweifel, Strickler et Associés --(associative)--> Communauté de travail bureau Zweifel + Strickler, U.S.P, S.V.I.L
#   Zweifel, Strickler et Associés --(associative)--> Uli Huber
#   Zweifel, Strickler et Associés --(associative)--> Maggia SA
#   Zweifel, Strickler et Associés --(associative)--> GERUA Groupe d'études de réalisation, Université de Annaba
#   Communauté de travail pour la construction de ruraux type expo 64 --(associative)--> A.S.C.A
#   Communauté de travail pour la construction de ruraux type expo 64 --(associative)--> S.V.I.L
#   Communauté de travail pour la construction de ruraux type expo 64 --(associative)--> U.S.P (Office de la construction Lausanne + Brugg)
#   Communauté de travail pour la construction de ruraux type expo 64 --(associative)--> Uli Huber
#   S.V.I.L --(associative)--> Communauté de travail bureau Zweifel + Strickler, U.S.P, S.V.I.L
#   Communauté de travail bureau Zweifel + Strickler, U.S.P, S.V.I.L --(associative)--> U.S.P (Office de la construction Lausanne + Brugg)
#   Communauté de travail bureau Zweifel + Strickler, U.S.P, S.V.I.L --(associative)--> Uli Huber
#   Maggia SA --(associative)--> GERUA Groupe d'études de réalisation, Université de Annaba
#   Maggia SA --(associative)--> Bonnard & Gardel
#   Maggia SA --(associative)--> Gruner AG
#   Maggia SA --(associative)--> Bonnard &amp; Gardel
#   GERUA Groupe d'études de réalisation, Université de Annaba --(associative)--> Bonnard &amp; Gardel
#   GERUA Groupe d'études de réalisation, Université de Annaba --(associative)--> Bonnard & Gardel
#   GERUA Groupe d'études de réalisation, Université de Annaba --(associative)--> Gruner AG
#   Bonnard &amp; Gardel --(associative)--> Pool d'ingénieurs
#   Bonnard & Gardel --(associative)--> Pool d'ingénieurs
#   Guido Cocchi --(associative)--> AAA/AD DECOPPET, Alin &amp; part.
#   Guido Cocchi --(associative)--> AAA/AD DECOPPET, Alin & part.
#   AAA/AD DECOPPET, Alin &amp; part. --(associative)--> Jacques Barbier
#   AAA/AD DECOPPET, Alin &amp; part. --(associative)--> Jean Brugger
#   AAA/AD DECOPPET, Alin &amp; part. --(associative)--> Alin Décoppet
#   AAA/AD DECOPPET, Alin &amp; part. --(associative)--> Nicolaus Herkommer
#   AAA/AD DECOPPET, Alin &amp; part. --(associative)--> Nicolas Petrovitch-Niegoch
#   AAA/AD DECOPPET, Alin &amp; part. --(associative)--> Pierre Rittmeyer
#   AAA/AD DECOPPET, Alin &amp; part. --(associative)--> Léopold Veuve
#   AAA/AD DECOPPET, Alin &amp; part. --(associative)--> René Vittone
#   AAA/AD DECOPPET, Alin &amp; part. --(associative)--> Michel-Robert Weber
#   AAA/AD DECOPPET, Alin &amp; part. --(associative)--> Roland Willomet
#   AAA/AD DECOPPET, Alin & part. --(associative)--> Jacques Barbier
#   AAA/AD DECOPPET, Alin & part. --(associative)--> Jean Brugger
#   AAA/AD DECOPPET, Alin & part. --(associative)--> Alin Décoppet
#   AAA/AD DECOPPET, Alin & part. --(associative)--> Nicolaus Herkommer
#   AAA/AD DECOPPET, Alin & part. --(associative)--> Nicolas Petrovitch-Niegoch
#   AAA/AD DECOPPET, Alin & part. --(associative)--> Pierre Rittmeyer
#   AAA/AD DECOPPET, Alin & part. --(associative)--> Léopold Veuve
#   AAA/AD DECOPPET, Alin & part. --(associative)--> René Vittone
#   AAA/AD DECOPPET, Alin & part. --(associative)--> Michel-Robert Weber
#   AAA/AD DECOPPET, Alin & part. --(associative)--> Roland Willomet
#   Alin Décoppet --()--> École polytechnique fédérale de Lausanne (EPFL)
#   École polytechnique fédérale de Lausanne (EPFL) --()--> Hubert Gilliéron
#   École polytechnique fédérale de Lausanne (EPFL) --()--> Pierre von Meiss
#   École polytechnique fédérale de Lausanne (EPFL) --()--> Jean-Pierre Vouga
#   École polytechnique fédérale de Lausanne (EPFL) --()--> Jean Stengelin
#   École polytechnique fédérale de Lausanne (EPFL) --()--> Jacques Favre
#   École polytechnique fédérale de Lausanne (EPFL) --()--> Jean-Pierre Daxelhofer
#   École polytechnique fédérale de Lausanne (EPFL) --(temporal-earlier)--> École polytechnique de l'Université de Lausanne (EPUL)
#   École polytechnique fédérale de Lausanne (EPFL) --()--> Philippe-H. Bovy
#   École polytechnique fédérale de Lausanne (EPFL) --()--> Alain-G. Tschumi
#   École polytechnique fédérale de Lausanne (EPFL) --()--> Inès Lamunière
#   École polytechnique fédérale de Lausanne (EPFL) --()--> Luigi Snozzi
#   École polytechnique fédérale de Lausanne (EPFL) --()--> Jean-Claude Badoux
#   École polytechnique fédérale de Lausanne (EPFL) --()--> Théodore Bovet
#   Pierre von Meiss --()--> École polytechnique de l'Université de Lausanne (EPUL)
#   École polytechnique de l'Université de Lausanne (EPUL) --()--> Jean-Pierre Vouga
#   École polytechnique de l'Université de Lausanne (EPUL) --()--> Jean Stengelin
#   École polytechnique de l'Université de Lausanne (EPUL) --()--> Jacques Favre
#   École polytechnique de l'Université de Lausanne (EPUL) --()--> Jean-Pierre Daxelhofer
#   École polytechnique de l'Université de Lausanne (EPUL) --()--> Maurice Cosandey
#   École polytechnique de l'Université de Lausanne (EPUL) --()--> Jean-Louis Ruche
#   École polytechnique de l'Université de Lausanne (EPUL) --(temporal-earlier)--> École d'ingénieurs de l'Université de Lausanne
#   Jean-Pierre Vouga --(family)--> Bernard Vouga
#   Jean-Pierre Vouga --()--> Ecole nationale supérieure des beaux-arts, Paris
#   Ecole nationale supérieure des beaux-arts, Paris --()--> Louis Viollier
#   Jacques Favre --(associative)--> Bernard Murisier
#   Bernard Murisier --(associative)--> Jacques Favarger
#   Jacques Favarger --(associative)--> Gaston Gorjat
#   Jacques Favarger --(associative)--> Roger Gonet
#   Gaston Gorjat --(associative)--> Robert Baehler
#   Maurice Cosandey --(associative)--> Zwahlen &amp; Mayr SA
#   Maurice Cosandey --(associative)--> Zwahlen & Mayr SA
#   Jean-Louis Ruche --(family)--> Maurice Ruche
#   Jean-Louis Ruche --()--> Jean Tschumi
#   Jean Tschumi --(family)--> Bernard Tschumi
#   Jean Tschumi --(associative)--> Pierre Bonnard
#   Jean Tschumi --()--> Lucio Di Clemente
#   Pierre Bonnard --(family)--> René Bonnard
#   René Bonnard --(associative)--> Edouard Boy de la Tour-Pilet
#   Inès Lamunière --(associative)--> Gabriel de Freudenreich
#   Gabriel de Freudenreich --(associative)--> André Gaillard
#   Jean-Marie Yokoyama --(associative)--> ETIC J.-M. Yokoyama
#   Alberto Sartoris --(family)--> Henri Ferrare
#   Alberto Sartoris --(family)--> Giovanni Sartoris
#   Alberto Sartoris --(family)--> Zoé Gionanna
#   Alberto Sartoris --(family)--> Carla Prina
#   Alberto Sartoris --(associative)--> Emmanuel Cattani
#   Alberto Sartoris --(associative)--> Roland Vuilleumier
#   Alberto Sartoris --()--> Guillaume Revillod
#   Alberto Sartoris --()--> Maurice Turettini
#   Guillaume Revillod --(associative)--> Maurice Turettini
#   Paul Lavenex --()--> Alphonse Laverrière
#   Alphonse Laverrière --(family)--> Ferdinand Jacques Meyrat
#   Alphonse Laverrière --(associative)--> Jean Taillens
#   Alphonse Laverrière --(associative)--> L'Œuvre (OEV)
#   Alphonse Laverrière --(associative)--> Eugène Monod
#   Alphonse Laverrière --(associative)--> Menuiserie Modèle Albert Held &amp; Cie. SA, Montreux
#   Alphonse Laverrière --(associative)--> Menuiserie Modèle Albert Held & Cie. SA, Montreux
#   Alphonse Laverrière --(associative)--> Pierre Quillet
#   Jean Taillens --(associative)--> Charles Dubois
#   L'Œuvre (OEV) --(associative)--> Henri-Robert Von der Mühll
#   Menuiserie Modèle Albert Held &amp; Cie. SA, Montreux --(family)--> Albert Held
#   Menuiserie Modèle Albert Held &amp; Cie. SA, Montreux --(associative)--> Georges Epitaux
#   Menuiserie Modèle Albert Held & Cie. SA, Montreux --(family)--> Albert Held
#   Menuiserie Modèle Albert Held & Cie. SA, Montreux --(associative)--> Georges Epitaux
#   Albert Held --(family)--> Alexandre Held
#   Pierre Zoelly --(associative)--> Roland Gay
#   Pierre Zoelly --(associative)--> Georges-Jacques Haefeli
#   Maurice Billeter --(associative)--> Jeanne Bueche
#   Maurice Billeter --(family)--> Béate Billeter-Oesterle
#   Jeanne Bueche --(associative)--> Béate Billeter-Oesterle
#   Jeanne Bueche --(family)--> Louis Bueche
#   Jeanne Bueche --(family)--> Jean-Pierre Bueche
#   Jeanne Bueche --(family)--> Florian Bueche
#   Jeanne Bueche --(family)--> Etienne Bueche
#   Louis Bueche --(family)--> Jean-Pierre Bueche
#   Louis Bueche --(family)--> Florian Bueche
#   Louis Bueche --(family)--> Etienne Bueche
#   Jean-Pierre Bueche --(family)--> Florian Bueche
#   Jean-Pierre Bueche --(family)--> Etienne Bueche
#   Florian Bueche --(family)--> Etienne Bueche
#   Frédéric de Morsier --(family)--> Henri de Morsier
#   Frédéric de Morsier --(associative)--> Charles Weibel
#   Frédéric de Morsier --(associative)--> Morsier et Weibel
#   Henri de Morsier --(associative)--> Charles Weibel
#   Henri de Morsier --(associative)--> Morsier et Weibel
#   Charles Weibel --(associative)--> Morsier et Weibel
#   Dominique Reverdin --(family)--> Raymond Reverdin
#   Louis de Vallière --(family)--> Famille de Vallière
#   Louis de Vallière --(family)--> Émile de Vallière
#   Famille de Vallière --(family)--> Émile de Vallière
#   Patrick Chiché --(associative)--> Dimitri Démétriadès
#   Patrick Chiché --(associative)--> Dimitri Papadaniel
#   Patrick Chiché --(associative)--> ACTE, Atelier d'Architecture
#   Dimitri Démétriadès --(associative)--> Dimitri Papadaniel
#   Dimitri Démétriadès --(associative)--> Atelier D. Démétriadès & D. Papadaniel
#   Dimitri Démétriadès --(associative)--> ACTE, Atelier d'Architecture
#   Dimitri Démétriadès --(associative)--> Atelier D. Démétriadès &amp; D. Papadaniel
#   Dimitri Papadaniel --(associative)--> Atelier D. Démétriadès &amp; D. Papadaniel
#   Dimitri Papadaniel --(associative)--> Atelier D. Démétriadès & D. Papadaniel
#   Dimitri Papadaniel --(associative)--> ACTE, Atelier d'Architecture
#   Maurice Bovey --(associative)--> Marcel Maillard
#   Tita Carloni --(associative)--> Rolf Wolfensberger
#   Tita Carloni --(associative)--> Ernst Gisel
#   Tita Carloni --(associative)--> Dolf Schnebli
#   René Lyon --(associative)--> Lyon &amp; Goldmann S.A.
#   René Lyon --(associative)--> Lyon & Goldmann S.A.
#   Fernand Dumas --(associative)--> Denis Honegger
#   Fernand Dumas --(family)--> Pierre Dumas
#   Fernand Dumas --(associative)--> Emilio Antognini
#   Denis Honegger --(associative)--> Emilio Antognini
#   Jacques Béguin --(family)--> Jean-Louis Béguin
#   Daniel Gudit --(associative)--> Marc Vogel
#   Jean Schlaeppi --(associative)--> Bernard Calame
#   Ugo Fovanna --(associative)--> Constantin de Charrière
#   Constantin de Charrière --(associative)--> Gilles Barbey
#   Charles Brugger --(family)--> Frédéric Brugger

# %%
nx.degree_centrality(graph)
# Out:
# {'Jacques de Freudenreich': 0.0,
#  'Casimir Reymond': 0.0,
#  'Alexandre Antipas': 0.0,
#  'Heidi Wenger': 0.006024096385542169,
#  'Peter Wenger': 0.006024096385542169,
#  'Charles-François Thévenaz': 0.012048192771084338,
#  'Charles-Philippe Thévenaz': 0.012048192771084338,
#  'Charles Thévenaz': 0.012048192771084338,
#  'Jacques Nobile': 0.0,
#  'Vincent Mangeat': 0.012048192771084338,
#  'Pierre Foretay': 0.006024096385542169,
#  'Fédération des Architectes Suisses (FAS) = Bund Schweizer Architekten (BSA)': 0.18072289156626506,
#  'Renato Salvi': 0.01807228915662651,
#  'Flora Ruchat-Roncati': 0.012048192771084338,
#  'Communauté de Travail la Transjurane': 0.012048192771084338,
#  'Georges Brera': 0.01807228915662651,
#  'Paul Waltenspühl': 0.012048192771084338,
#  'Jean-Marie Ellenberger': 0.024096385542168676,
#  'Jean-Jacques Gerber': 0.006024096385542169,
#  'Bernard Mocellin': 0.006024096385542169,
#  'André Leman': 0.006024096385542169,
#  'Max Schlup': 0.006024096385542169,
#  'Jakob Zweifel': 0.024096385542168676,
#  'H. Massler': 0.012048192771084338,
#  'Team J. Zweifel': 0.04819277108433735,
#  'W. Maurer': 0.01807228915662651,
#  'W. Christen': 0.024096385542168676,
#  'Zweifel, Strickler et Associés': 0.042168674698795185,
#  'Communauté de travail pour la construction de ruraux type expo 64': 0.03614457831325302,
#  'A.S.C.A': 0.006024096385542169,
#  'S.V.I.L': 0.012048192771084338,
#  'Communauté de travail bureau Zweifel + Strickler, U.S.P, S.V.I.L': 0.042168674698795185,
#  'U.S.P (Office de la construction Lausanne + Brugg)': 0.012048192771084338,
#  'Uli Huber': 0.024096385542168676,
#  'Maggia SA': 0.024096385542168676,
#  "GERUA Groupe d'études de réalisation, Université de Annaba": 0.024096385542168676,
#  'Bonnard &amp; Gardel': 0.009036144578313254,
#  'Bonnard & Gardel': 0.009036144578313254,
#  "Pool d'ingénieurs": 0.006024096385542169,
#  'Gruner AG': 0.012048192771084338,
#  'H. Menig': 0.006024096385542169,
#  'Guido Cocchi': 0.012048192771084338,
#  'AAA/AD DECOPPET, Alin &amp; part.': 0.03313253012048193,
#  'AAA/AD DECOPPET, Alin & part.': 0.03313253012048193,
#  'Jacques Barbier': 0.006024096385542169,
#  'Jean Brugger': 0.006024096385542169,
#  'Alin Décoppet': 0.012048192771084338,
#  'École polytechnique fédérale de Lausanne (EPFL)': 0.08433734939759037,
#  'Hubert Gilliéron': 0.006024096385542169,
#  'Pierre von Meiss': 0.012048192771084338,
#  "École polytechnique de l'Université de Lausanne (EPUL)": 0.05421686746987952,
#  'Jean-Pierre Vouga': 0.030120481927710843,
#  'Bernard Vouga': 0.006024096385542169,
#  'Ecole nationale supérieure des beaux-arts, Paris': 0.012048192771084338,
#  'Louis Viollier': 0.006024096385542169,
#  'Jean Stengelin': 0.012048192771084338,
#  'Jacques Favre': 0.01807228915662651,
#  'Bernard Murisier': 0.012048192771084338,
#  'Jacques Favarger': 0.01807228915662651,
#  'Gaston Gorjat': 0.012048192771084338,
#  'Robert Baehler': 0.006024096385542169,
#  'Roger Gonet': 0.006024096385542169,
#  'Jean-Pierre Daxelhofer': 0.012048192771084338,
#  'Maurice Cosandey': 0.012048192771084338,
#  'Zwahlen &amp; Mayr SA': 0.0030120481927710845,
#  'Zwahlen & Mayr SA': 0.0030120481927710845,
#  'Jean-Louis Ruche': 0.01807228915662651,
#  'Maurice Ruche': 0.006024096385542169,
#  'Jean Tschumi': 0.030120481927710843,
#  'Bernard Tschumi': 0.006024096385542169,
#  'Pierre Bonnard': 0.012048192771084338,
#  'René Bonnard': 0.012048192771084338,
#  'Edouard Boy de la Tour-Pilet': 0.006024096385542169,
#  'Lucio Di Clemente': 0.006024096385542169,
#  "École d'ingénieurs de l'Université de Lausanne": 0.006024096385542169,
#  'Philippe-H. Bovy': 0.006024096385542169,
#  'Alain-G. Tschumi': 0.006024096385542169,
#  'Inès Lamunière': 0.012048192771084338,
#  'Gabriel de Freudenreich': 0.01807228915662651,
#  'André Gaillard': 0.006024096385542169,
#  'Luigi Snozzi': 0.006024096385542169,
#  'Jean-Claude Badoux': 0.006024096385542169,
#  'Théodore Bovet': 0.006024096385542169,
#  'Nicolaus Herkommer': 0.006024096385542169,
#  'Nicolas Petrovitch-Niegoch': 0.006024096385542169,
#  'Pierre Rittmeyer': 0.006024096385542169,
#  'Léopold Veuve': 0.006024096385542169,
#  'René Vittone': 0.006024096385542169,
#  'Michel-Robert Weber': 0.006024096385542169,
#  'Roland Willomet': 0.006024096385542169,
#  'Jean-Marie Yokoyama': 0.012048192771084338,
#  'ETIC J.-M. Yokoyama': 0.006024096385542169,
#  'Alberto Camenzind': 0.006024096385542169,
#  'Florian Vischer': 0.006024096385542169,
#  'Alberto Sartoris': 0.05421686746987952,
#  'Henri Ferrare': 0.006024096385542169,
#  'Giovanni Sartoris': 0.006024096385542169,
#  'Zoé Gionanna': 0.006024096385542169,
#  'Carla Prina': 0.006024096385542169,
#  'Emmanuel Cattani': 0.006024096385542169,
#  'Roland Vuilleumier': 0.006024096385542169,
#  'Guillaume Revillod': 0.012048192771084338,
#  'Maurice Turettini': 0.01807228915662651,
#  'Paul Lavenex': 0.012048192771084338,
#  'Alphonse Laverrière': 0.04819277108433735,
#  'Ferdinand Jacques Meyrat': 0.006024096385542169,
#  'Jean Taillens': 0.012048192771084338,
#  'Charles Dubois': 0.006024096385542169,
#  "L'Œuvre (OEV)": 0.012048192771084338,
#  'Henri-Robert Von der Mühll': 0.006024096385542169,
#  'Eugène Monod': 0.006024096385542169,
#  'Menuiserie Modèle Albert Held &amp; Cie. SA, Montreux': 0.009036144578313254,
#  'Menuiserie Modèle Albert Held & Cie. SA, Montreux': 0.009036144578313254,
#  'Albert Held': 0.012048192771084338,
#  'Alexandre Held': 0.006024096385542169,
#  'Georges Epitaux': 0.012048192771084338,
#  'Pierre Quillet': 0.006024096385542169,
#  'Frédéric Gilliard': 0.006024096385542169,
#  'Pierre Zoelly': 0.01807228915662651,
#  'Roland Gay': 0.006024096385542169,
#  'Georges-Jacques Haefeli': 0.012048192771084338,
#  'Arthur Lozeron': 0.006024096385542169,
#  'Robert Loup': 0.006024096385542169,
#  'Jean Pythoud': 0.006024096385542169,
#  'Janos Farago': 0.006024096385542169,
#  'Maurice Billeter': 0.01807228915662651,
#  'Jeanne Bueche': 0.042168674698795185,
#  'Béate Billeter-Oesterle': 0.012048192771084338,
#  'Louis Bueche': 0.024096385542168676,
#  'Jean-Pierre Bueche': 0.024096385542168676,
#  'Florian Bueche': 0.024096385542168676,
#  'Etienne Bueche': 0.024096385542168676,
#  'Marc Piccard': 0.006024096385542169,
#  'Max Bill': 0.006024096385542169,
#  'Eduard Lanz': 0.006024096385542169,
#  'Harry Wyss': 0.0,
#  'Mario Bevilacqua': 0.0,
#  'Alphonse Andrey': 0.0,
#  'Benjamin Recordon': 0.0,
#  'Albert Cuony': 0.0,
#  'Frédéric de Morsier': 0.01807228915662651,
#  'Henri de Morsier': 0.01807228915662651,
#  'Charles Weibel': 0.01807228915662651,
#  'Morsier et Weibel': 0.01807228915662651,
#  'Marcel Waeber': 0.0,
#  'Dominique Reverdin': 0.006024096385542169,
#  'Raymond Reverdin': 0.006024096385542169,
#  'Louis de Vallière': 0.012048192771084338,
#  'Famille de Vallière': 0.012048192771084338,
#  'Émile de Vallière': 0.012048192771084338,
#  'Louis Dumas': 0.0,
#  'Claude Wasserfallen': 0.0,
#  'John Gros': 0.0,
#  'Albert Cornaz': 0.0,
#  'Paul Dumartheray': 0.0,
#  'Hans Schmidt': 0.0,
#  'Robert Capt': 0.0,
#  'Edmond Fatio': 0.0,
#  'Oscar Oulevey': 0.0,
#  'Marc Burgener': 0.0,
#  'Anne Torcapel': 0.0,
#  'François Wavre': 0.0,
#  'John Camoletti': 0.0,
#  'Patrick Chiché': 0.01807228915662651,
#  'Dimitri Démétriadès': 0.024096385542168676,
#  'Dimitri Papadaniel': 0.024096385542168676,
#  'Atelier D. Démétriadès &amp; D. Papadaniel': 0.006024096385542169,
#  'Atelier D. Démétriadès & D. Papadaniel': 0.006024096385542169,
#  "ACTE, Atelier d'Architecture": 0.01807228915662651,
#  'René Chapallaz': 0.0,
#  'Edouard Weber': 0.0,
#  'Oscar Magnin': 0.0,
#  'Alexandre Pilet': 0.0,
#  'Maurice Bovey': 0.006024096385542169,
#  'Marcel Maillard': 0.006024096385542169,
#  'Etienne Porret': 0.0,
#  'Charles Zimmermann': 0.0,
#  'Adolphe Burnat': 0.0,
#  'Tita Carloni': 0.01807228915662651,
#  'Rolf Wolfensberger': 0.006024096385542169,
#  'Ernst Gisel': 0.006024096385542169,
#  'Dolf Schnebli': 0.006024096385542169,
#  'E. Schmidt': 0.0,
#  'René Berger': 0.0,
#  'Alfred Aubert': 0.0,
#  'Charles Zbinden': 0.0,
#  'Jean-Maurice Bommer': 0.0,
#  'Fritz Schlup': 0.0,
#  'Roland Mosimann': 0.0,
#  'Pierre Jeanneret': 0.0,
#  'Italo Ferrari': 0.0,
#  'Georges Charles Jean Chessex': 0.0,
#  'Karl Moser': 0.0,
#  'Justus Dahinden': 0.0,
#  'René Lyon': 0.006024096385542169,
#  'Lyon &amp; Goldmann S.A.': 0.0030120481927710845,
#  'Lyon & Goldmann S.A.': 0.0030120481927710845,
#  'Joseph Austermayer': 0.0,
#  'Marc Mozer': 0.0,
#  'Fernand Dumas': 0.01807228915662651,
#  'Denis Honegger': 0.012048192771084338,
#  'Pierre Dumas': 0.006024096385542169,
#  'Emilio Antognini': 0.012048192771084338,
#  'Daniel Girardet': 0.0,
#  'Luca Merlini': 0.0,
#  'Albert Baud': 0.0,
#  'Raymond Pizzera': 0.0,
#  'Pierre Bechler': 0.0,
#  'Charles Coigny': 0.0,
#  'Max Richter': 0.0,
#  'François-Charles Hoguer': 0.0,
#  'Marcel Gut': 0.0,
#  'Werner Oesch': 0.0,
#  'Ernest Martin': 0.0,
#  'Jacques Béguin': 0.006024096385542169,
#  'Jean-Louis Béguin': 0.006024096385542169,
#  'Eric Musy': 0.0,
#  'Arnold Itten': 0.0,
#  'Marcel Colliard': 0.0,
#  'Lucien Meisser': 0.0,
#  'H. Python': 0.0,
#  'Chappuis': 0.0,
#  'Roger Lack': 0.0,
#  'Alfred Hoch': 0.0,
#  'Beda Hefti': 0.0,
#  'François Neyroud': 0.0,
#  'Jean-Pierre Cahen': 0.0,
#  'Henri Lesemann': 0.0,
#  'Francis Isoz': 0.0,
#  'Gérard Châtelain': 0.0,
#  'Otto Pfleghard': 0.0,
#  'Jacques Dumas': 0.0,
#  'Frédéric Broillet': 0.0,
#  'Maurice Braillard': 0.0,
#  'Alban Gerster': 0.0,
#  'Jean Camoletti': 0.0,
#  'E. Bertallo': 0.0,
#  'Charles-Albert Wulffleff': 0.0,
#  'Léon Hertling': 0.0,
#  'Georges Mercier': 0.0,
#  'Joseph-Marc Saugey': 0.0,
#  'Michel Polak': 0.0,
#  'Christian Eicher': 0.0,
#  'Bruno Marchand': 0.0,
#  'Paul Morisod': 0.0,
#  'Edmond Virieux': 0.0,
#  'Charles-François Bonjour': 0.0,
#  'Robert Longchamp': 0.0,
#  'Donato Burgener': 0.0,
#  'Jacques Schader': 0.0,
#  'Paul Lorenz': 0.0,
#  'François Maurice': 0.0,
#  'Arthur Studer': 0.0,
#  'Daniel Gudit': 0.006024096385542169,
#  'Marc Vogel': 0.006024096385542169,
#  'Henri Collomb': 0.0,
#  'Wilhelm Bracher': 0.0,
#  'Gaston Membrez': 0.0,
#  'Rudolf Schoch': 0.0,
#  'Marx Levy': 0.0,
#  'Thomas Urfer': 0.0,
#  'Adrien Van Dorsser': 0.0,
#  'Von Sinner': 0.0,
#  'Mario Botta': 0.0,
#  'Bernard Meuwly': 0.0,
#  'Edmond Quillet': 0.0,
#  'René Gerster': 0.0,
#  'Marcel Daxelhoffer': 0.0,
#  'Alfred Daulte': 0.0,
#  'Michel Magnin': 0.0,
#  'Pierre-Marie Bonvin': 0.0,
#  'Charles Liechti': 0.0,
#  'Jacques Maillard': 0.0,
#  'Georges Addor': 0.0,
#  'Pierre Vincent': 0.0,
#  'Fernand Decker': 0.0,
#  'Hans Schaffner': 0.0,
#  'Jean Schlaeppi': 0.006024096385542169,
#  'Bernard Calame': 0.006024096385542169,
#  'Robert Maillart': 0.0,
#  'Alain Ritter': 0.0,
#  'Henri Meyer': 0.0,
#  'A. Pache': 0.0,
#  'Georges Lerch': 0.0,
#  'Jean-Marc Lamunière': 0.0,
#  'Ugo Fovanna': 0.006024096385542169,
#  'Constantin de Charrière': 0.012048192771084338,
#  'Gilles Barbey': 0.006024096385542169,
#  'Hunziker': 0.0,
#  'Paul Bournoud': 0.0,
#  'Ernst Baumgart': 0.0,
#  'Maurice Grivel': 0.0,
#  'Jacques Suard': 0.0,
#  'Karl Egender': 0.0,
#  'Edmond Calame': 0.0,
#  'Patrick Devanthéry': 0.0,
#  'Charles Jeanneret': 0.0,
#  'Albert Cingria': 0.0,
#  'Rino Tami': 0.0,
#  'Alphonse Schorp': 0.0,
#  'Atelier Cube': 0.0,
#  'Ernest Prince': 0.0,
#  'Jean Suter': 0.0,
#  'Eugène Jost': 0.0,
#  'Christian Beck': 0.0,
#  'Arthur Lerch': 0.0,
#  'Jean-Louis Cayla': 0.0,
#  'Jean Perrelet': 0.0,
#  'Albert Carl Angst': 0.0,
#  'Walter Baumann': 0.0,
#  'René Schwertz': 0.0,
#  'Eugène Mamin': 0.0,
#  'Eugène Béboux': 0.0,
#  'Patrick Mestelan': 0.0,
#  'Maximilien de Rham': 0.0,
#  'Edmond Guex': 0.0,
#  'Eugène Henssler': 0.0,
#  'Charles Gunthert': 0.0,
#  'Maurice Schnell': 0.0,
#  'Jean-Pierre Borgeaud': 0.0,
#  'Frédéric Aubry': 0.0,
#  'Charles Brugger': 0.006024096385542169,
#  'Frédéric Brugger': 0.006024096385542169,
#  'Frantz Fulpius': 0.0,
#  'Robert Monnier': 0.0,
#  'Hans Brechbühler': 0.0,
#  'Marcel Bussy': 0.0,
#  'Robert Linder': 0.0,
#  'Franz Füeg': 0.0,
#  'Paul Vallotton': 0.0,
#  'Alphonse Guignet': 0.0,
#  'Michel Fantoli': 0.0,
#  'Jean Béguin': 0.0}
